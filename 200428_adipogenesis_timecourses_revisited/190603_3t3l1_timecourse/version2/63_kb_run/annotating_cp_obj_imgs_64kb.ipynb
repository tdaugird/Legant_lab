# %% [markdown]
# ### This is for mannually creating list of objects to be kept and objects to discard in hopes of finding a couple of parameters that should be used to filter things. This script is adapted from the original in order to generates some test data for the new image set.

# %%
import os
import numpy as np
import pandas as pd
from skimage import io
# %matplotlib qt
import matplotlib.pyplot as plt
from scipy import stats

# %%
'''set up some variables that are directory for images and .csv etc. '''
#directory for segmented images
segm_img_dir = r'Z:\TAD\200428_adipogenesis_timecourses_revisited\190603_3t3l1_timecourse\cp_output_imgs63kb\set2_right_maybe'
#directory for cell profiler output .csv
cp_csv_dir = r'C:\Users\LegantLab\Documents\git\tad\Legant_lab\200428_adipogenesis_timecourses_revisited\190603_3t3l1_timecourse\version2\63_kb_run'
#file name for cell profiler output .csv
cp_csv = 'MyExpt_nuclei.csv'
#file nmae for the image list .csv
img_id_csv = 'img_ids_63kb.csv'
#directory to place annotated .csv
annotated_csv_dir = r'C:\Users\LegantLab\Documents\git\tad\Legant_lab\200428_adipogenesis_timecourses_revisited\190603_3t3l1_timecourse\version2\63_kb_run\annotated_csv'

# %% [markdown]
# ###  I will need to do a little bit of manual work here as opposed to the original code which was more automated

# %% [markdown]
# ### the base directoy for all of the orignal images: Z:\TAD\190603_3t3l1_timecourse

# %%
orig_file_lst = []
orig_img_lst = []


'''pull image from t2d'''
os.chdir(r'Z:\TAD\190603_3t3l1_timecourse\t4h\64kb_imgs')
img_t2d_name = 'img172-c1.tiff'
img_orig_t2d = io.imread(img_t2d_name)
orig_file_lst.append(img_t2d_name)
orig_img_lst.append(img_orig_t2d)

#img_t2d_name2 = 'img1816-c1.tiff'
#img_orig_t2d2 = io.imread(img_t2d_name2)
#orig_file_lst.append(img_t2d_name2)
#orig_img_lst.append(img_orig_t2d2)
#
#img_t2d_name3 = 'img1821-c1.tiff'
#img_orig_t2d3 = io.imread(img_t2d_name3)
#orig_file_lst.append(img_t2d_name3)
#orig_img_lst.append(img_orig_t2d3)
#
#img_t2d_name4 = 'img1822-c1.tiff'
#img_orig_t2d4 = io.imread(img_t2d_name4)
#orig_file_lst.append(img_t2d_name4)
#orig_img_lst.append(img_orig_t2d4)
#
#'''pull image from t4d'''
#os.chdir(r'Z:\TAD\190603_3t3l1_timecourse\t4d\8kb_imgs')
#img_t4d_name = 'img1852-c1.tiff'
#img_orig_t4d = io.imread(img_t4d_name)
#orig_file_lst.append(img_t4d_name)
#orig_img_lst.append(img_orig_t4d)
#
#img_t4d_name2 = 'img1854-c1.tiff'
#img_orig_t4d2 = io.imread(img_t4d_name2)
#orig_file_lst.append(img_t4d_name2)
#orig_img_lst.append(img_orig_t4d2)
#
#'''pull images from t6d'''
#os.chdir(r'Z:\TAD\190603_3t3l1_timecourse\t6d\8kb_imgs')
#img_t6d_name = 'img1884-c1.tiff'
#img_orig_t6d = io.imread(img_t6d_name)
#orig_file_lst.append(img_t6d_name)
#orig_img_lst.append(img_orig_t6d)
#
#img_t6d_name3 = 'img1884-c1.tiff'
#img_orig_t6d3 = io.imread(img_t6d_name3)
#orig_file_lst.append(img_t6d_name3)
#orig_img_lst.append(img_orig_t6d3)

#img_t6d_name2 = 'img1881-c1.tiff'
#img_orig_t6d2 = io.imread(img_t6d_name2)
#orig_file_lst.append(img_t6d_name2)
#orig_img_lst.append(img_orig_t6d2)



base_name_numb = 7 #this is the last number within the image name string to use for the .csv outputs a little later

# %% [markdown]
# ### I merged the net couple of lines that genreate lists into the above code. I think that it makes for a little clearner organizaiton down the line

# %%
'''list of original filenames'''
#orig_file_lst = [img_t2d_name, img_t2d_name2, img_t2d_name3, img_t2d_name4,
#                 img_t4d_name, img_t4d_name2, img_t6d_name, img_t6d_name2]
# Out:
# 'list of original filenames'

# %%
#'''list of original images '''
#img_orig_lst = [img_orig_t2d, img_orig_t2d2, img_orig_t2d3, img_orig_t2d4, 
 #               img_orig_t4d, img_orig_t4d2, img_orig_t6d, img_orig_t6d2]

# %%
'''directory of segm imgs'''
os.chdir(segm_img_dir)

# %%
'''read in segmented images'''
img_segm_lst = []

img_segm_t2d = io.imread(img_t2d_name)
img_segm_lst.append(img_segm_t2d)
#img_segm_t2d2 = io.imread(img_t2d_name2)
#img_segm_lst.append(img_segm_t2d2)
#img_segm_t2d3 = io.imread(img_t2d_name3)
#img_segm_lst.append(img_segm_t2d3)
#img_segm_t2d4 = io.imread(img_t2d_name4)
#img_segm_lst.append(img_segm_t2d4)
#img_segm_t4d = io.imread(img_t4d_name)
#img_segm_lst.append(img_segm_t4d)
#img_segm_t4d2 = io.imread(img_t4d_name2)
#img_segm_lst.append(img_segm_t4d2)
#img_segm_t6d = io.imread(img_t6d_name)
#img_segm_lst.append(img_segm_t6d)
#img_segm_t6d2 = io.imread(img_t6d_name)
#img_segm_lst.append(img_segm_t6d)

# %%
#img_segm_lst = [img_segm_t2d, img_segm_t2d2, img_segm_t2d3, img_segm_t2d4, img_segm_t4d, img_segm_t6d, img_segm_t6d2]

# %% [markdown]
# ### I now need to find what the corresponding image numbers are in the cellProfiler output .csv files

# %%
'''change to directory with the CP output .csv files'''
os.chdir(cp_csv_dir)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'annotated_csv',
#  'annotating_cp_obj_imgs.ipynb',
#  'annotating_cp_obj_imgs_64kb.ipynb',
#  'classifier_testing.ipynb',
#  'img_ids_63kb.csv',
#  'MyExpt_Experiment.csv',
#  'MyExpt_Image.csv',
#  'MyExpt_nuclei.csv',
#  'segm_190603_revist_63kb_run.cpproj',
#  'segm_imgs.cpproj']

# %%
'''read in the .csv files'''
df_whole = pd.read_csv(cp_csv)
img_lst_df = pd.read_csv(img_id_csv)

'''this will give an array of the corresponding ImageNumber for each image in the MyExpt_nuclei.csv dataframe'''
img_num_arr = np.array(img_lst_df[img_lst_df.FileName_dapi.isin(orig_file_lst)]['Group_Index'])

# %%
img_num_arr
# Out:
# array([5], dtype=int64)

# %%
'''input the index from the image name and output a dataframe that has statistics for that image. This also
makes a subplot with the segmented image the original image and plot that shows where object is located'''


iter_id = 0

'''set up file names and associated image number'''
#orig_img_file = orig_img_lst[iter_id]
#segm_img_file = segm_img_lst[iter_id]   
image_number = img_num_arr[iter_id]
orig_img = orig_img_lst[iter_id]
segm_img = img_segm_lst[iter_id]

'''parse out a df that contains only information about the desired img'''
df = df_whole.loc[df_whole.ImageNumber == image_number]


'''also need a df that has all of the categories'''
df_all_cats = df.copy()

'''categories for manual curation of list of objects to keep and toss'''
cats = ['ObjectNumber',
        'AreaShape_Center_X',
        'AreaShape_Center_Y',
        'AreaShape_Area',
           'AreaShape_Eccentricity']
df = df[cats] #keep only a couple of the categories

#'''read in the original image'''
#os.chdir(orig_img_dir)
#orig_img = io.imread(orig_img_file)


#'''read in the segmented image'''
#os.chdir(segm_img_dir)
#segm_img = io.imread(segm_img_file)


'''make a plot that contains the orignal image, the segmented image as well as a quick plot using the x and y positions from the data frame'''
fig, axes = plt.subplots(1, 3)
axes = axes.flatten()
axes[0].imshow(orig_img)
axes[1].imshow(segm_img)
axes[2].scatter(df.AreaShape_Center_X, df.AreaShape_Center_Y)
axes[2].invert_yaxis()

# %%
'''print off sorted df to annotate objects'''
df.sort_values('AreaShape_Center_X', inplace = True)
#df.loc[df.AreaShape_Area]
df.loc[df.AreaShape_Area >= 10000][70:900]

# in = [7, 33, 51, 69, 77, 47, 63, 89, 128, 138]
#out = [123, 132,  140, 142, 73, 133, 115, 46, 43, 45, 56]
# Out:
#      ObjectNumber  AreaShape_Center_X  AreaShape_Center_Y  AreaShape_Area  \
# 893           138              2939.0              5068.0           59289
# 775            20              2983.0               710.0           56439
# 809            54              2995.0              1995.0           62099
# 883           128              3071.0              4470.0           43275
# 792            37              3089.0              1422.0           37581
# 801            46              3136.0              1706.0           53975
# 816            61              3175.0              2282.0           47882
# 844            89              3180.0              3308.0           39588
# 763             8              3284.0               254.0           37435
# 799            44              3371.0              1688.0           35463
# 868           113              3374.0              3849.0          101077
# 818            63              3403.0              2322.0           42784
# 830            75              3522.0              2829.0           42441
# 760             5              3541.0               202.0           39941
# 835            80              3572.0              3091.0           34484
# 800            45              3645.0              1766.0           76260
# 850            95              3666.0              3394.0           60073
# 768            13              3763.0               411.0           42329
# 773            18              3848.0               696.0           60848
# 900           145              3901.0              5487.0          169146
# 870           115              3932.0              3916.0           60201
# 836            81              3938.0              3085.0           52771
# 802            47              3952.0              1724.0           43711
# 861           106              3969.0              3654.0           53027
# 794            39              4084.0              1448.0           41226
# 811            56              4173.0              2100.0           70454
# 817            62              4222.0              2290.0           48874
# 823            68              4295.0              2539.0           66033
# 845            90              4346.0              3324.0           10808
# 831            76              4375.0              3029.0           78281
# 772            17              4405.0               492.0           50505
# 889           134              4472.0              4707.0           46937
# 858           103              4502.0              3586.0           36415
# 759             4              4575.0               132.0           51298
# 834            79              4592.0              3056.0           31565
# 886           131              4683.0              4563.0           70660
# 872           117              4719.0              4003.0           47048
# 805            50              4730.0              1839.0           48905
# 896           141              4793.0              5175.0           46205
# 840            85              4799.0              3180.0           43917
# 827            72              4868.0              2681.0           49009
# 862           107              4995.0              3667.0           41100
# 891           136              5053.0              4952.0           32251
# 826            71              5119.0              2646.0           39944
# 888           133              5130.0              4622.0           88581
# 899           144              5152.0              5243.0           36993
# 795            40              5169.0              1480.0           40459
# 781            26              5219.0               839.0           90378
# 769            14              5248.0               466.0           43618
# 842            87              5251.0              3209.0           47177
# 804            49              5271.0              1835.0           29488
# 859           104              5351.0              3631.0           35262
# 815            60              5524.0              2208.0           45634
# 871           116              5526.0              3937.0           45395
# 876           121              5592.0              4184.0           40270
# 790            35              5606.0              1392.0           33525
# 770            15              5669.0               531.0           32443
# 894           139              5691.0              5035.0           21477
# 902           147              5691.0              5556.0           58951
#
#      AreaShape_Eccentricity
# 893                0.655774
# 775                0.753780
# 809                0.767006
# 883                0.746129
# 792                0.737718
# 801                0.800017
# 816                0.688898
# 844                0.699416
# 763                0.592892
# 799                0.801636
# 868                0.580149
# 818                0.756094
# 830                0.582524
# 760                0.506932
# 835                0.839812
# 800                0.883846
# 850                0.695489
# 768                0.676105
# 773                0.539445
# 900                0.787615
# 870                0.521804
# 836                0.757027
# 802                0.683781
# 861                0.765452
# 794                0.619036
# 811                0.756051
# 817                0.853936
# 823                0.611221
# 845                0.568908
# 831                0.855427
# 772                0.660271
# 889                0.606994
# 858                0.413662
# 759                0.540244
# 834                0.542754
# 886                0.602034
# 872                0.762873
# 805                0.703726
# 896                0.749835
# 840                0.461252
# 827                0.605726
# 862                0.670773
# 891                0.840876
# 826                0.475812
# 888                0.856233
# 899                0.512369
# 795                0.467157
# 781                0.826104
# 769                0.490435
# 842                0.784699
# 804                0.572152
# 859                0.600121
# 815                0.696968
# 871                0.445028
# 876                0.574213
# 790                0.554044
# 770                0.692534
# 894                0.834040
# 902                0.869957

# %%
'''this is list of objects not included in the out list'''
out_obj_lst_annot = [39, 36, 40, 25, 12, 7, 2]
out_obj_lst_small = np.array(df.loc[df.AreaShape_Area < 10000].ObjectNumber)
out_obj_lst_large = np.array(df.loc[df.AreaShape_Area > 110000].ObjectNumber)
out_obj_lst_concat = np.concatenate([out_obj_lst_annot, out_obj_lst_small, out_obj_lst_large])
in_obj_lst = np.setdiff1d(np.unique(df.ObjectNumber), out_obj_lst_concat, assume_unique=False)

# %%
'''anotate the in objects'''
in_obj_lst  = [19, 26, 34, 33, 42, 43, 41, 21, 11]
in_obj_lst = np.unique(in_obj_lst)
out_obj_lst_concat = np.setdiff1d(np.unique(df.ObjectNumber), in_obj_lst, assume_unique=False)

# %%
in_obj_lst = [7, 33, 51, 69, 77, 47, 63, 89, 128, 138]
out_obj_lst_concat = [123, 132,  140, 142, 73, 133, 115, 46, 43, 45, 56]

# in = [7, 33, 51, 69, 77, 47, 63, 89, 128, 138]
#out = [123, 132,  140, 142, 73, 133, 115, 46, 43, 45, 56]

# %%
df_in = df_all_cats.loc[df_all_cats.ObjectNumber.isin(in_obj_lst)]
df_out = df_all_cats.loc[df_all_cats.ObjectNumber.isin(out_obj_lst_concat)]

# %%
'''ax = plt.scatter(df_in.AreaShape_Center_X, df_in.AreaShape_Center_Y,
                color = 'r')'''
# Out:
# "ax = plt.scatter(df_in.AreaShape_Center_X, df_in.AreaShape_Center_Y,\n                color = 'r')"

# %%
df_in
# Out:
#      ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_Center_X  \
# 603           20            11           30048              1318.0
# 608           20            16           60167              1262.0
# 611           20            19           40307              1280.0
# 612           20            20           47324               190.0
#
#      AreaShape_Center_Y  AreaShape_Center_Z  AreaShape_Compactness  \
# 603               559.0                 1.0               1.013953
# 608              1365.0                 1.0               1.011963
# 611              1673.0                 1.0               1.036531
# 612              1688.0                 1.0               1.019382
#
#      AreaShape_Eccentricity  AreaShape_EulerNumber  AreaShape_Extent  ...  \
# 603                0.513869                    1.0          0.809810  ...
# 608                0.458481                    1.0          0.758459  ...
# 611                0.602514                    1.0          0.728457  ...
# 612                0.532647                    1.0          0.767474  ...
#
#      Location_MaxIntensity_X_cebp  Location_MaxIntensity_X_dapi  \
# 603                        1286.0                        1303.0
# 608                        1282.0                        1308.0
# 611                        1284.0                        1260.0
# 612                         261.0                         196.0
#
#      Location_MaxIntensity_X_ppar  Location_MaxIntensity_Y_cebp  \
# 603                        1335.0                         553.0
# 608                        1268.0                        1422.0
# 611                        1260.0                        1689.0
# 612                         188.0                        1710.0
#
#      Location_MaxIntensity_Y_dapi  Location_MaxIntensity_Y_ppar  \
# 603                         576.0                         541.0
# 608                        1355.0                        1279.0
# 611                        1672.0                        1647.0
# 612                        1739.0                        1726.0
#
#      Location_MaxIntensity_Z_cebp  Location_MaxIntensity_Z_dapi  \
# 603                           0.0                           0.0
# 608                           0.0                           0.0
# 611                           0.0                           0.0
# 612                           0.0                           0.0
#
#      Location_MaxIntensity_Z_ppar  Number_Object_Number
# 603                           0.0                    11
# 608                           0.0                    16
# 611                           0.0                    19
# 612                           0.0                    20
#
# [4 rows x 118 columns]

# %%
plt.scatter(df_in.AreaShape_Center_X, 
           df_in.AreaShape_Center_Y, color = 'r')

# %%
os.chdir(annotated_csv_dir)
base_name = orig_file_lst[iter_id][:base_name_numb]

df_in.to_csv('df_in_'+base_name+'.csv')
df_out.to_csv('df_out_'+base_name+'.csv')

# %%
orig_file_lst[iter_id][:base_name_numb]

# %%
len(df_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-9d232418166a> in <module>
# ----> 1 len(df_test)
#
# NameError: name 'df_test' is not defined

# %% [markdown]
# # the rest is from the original file

# %%
'''list of the segmented images'''
segm_img_lst =os.listdir()

# %%
'''the original images are saved as .tif file while the segmented images are saved as .tiff files so I just need to go though and make a quick adjustment'''

orig_img_lst = []
for i in segm_img_lst:
    orig_img_lst.append(i[:-1])
orig_img_lst
# Out:
# ['stad445-xy04_c4_mid.tif',
#  'stad445-xy09_c4_mid.tif',
#  'stad446-xy09_c4_mid.tif',
#  'stad446-xy10_c4_mid.tif',
#  'stad447-xy03_c4_mid.tif']

# %%
#need 436 and 444

# %%
'''dir with .csv files'''
os.chdir(r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output')

# %%
'''data frame with the file names of the orginal input to cell profiler'''
img_lst_df = pd.read_csv('img_ls.csv')

# %%
'''this will give an array of the corresponding ImageNumber for each image in the MyExpt_nuclei.csv dataframe'''
img_num_arr = np.array(img_lst_df[img_lst_df.FileName_dapi.isin(orig_img_lst)]['Group_Index'])

# %%
df_whole = pd.read_csv('MyExpt_nuclei.csv')

# %%
img_num_arr
# Out:
# array([ 94,  99, 109, 110, 113], dtype=int64)

# %%
img_dict = {}

for i in range(len(segm_img_lst)):
    img_dict.update({segm_img_lst[i] : img_num_arr[i]})
    
img_dict
# Out:
# {'stad445-xy04_c4_mid.tiff': 94,
#  'stad445-xy09_c4_mid.tiff': 99,
#  'stad446-xy09_c4_mid.tiff': 109,
#  'stad446-xy10_c4_mid.tiff': 110,
#  'stad447-xy03_c4_mid.tiff': 113}

# %%
'''change to directory with the images'''
os.chdir(r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests\segm_imgs\v2')

# %%
orig_img_dir = r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests'
segm_img_dir = r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests\segm_imgs\v2'

# %%
# %matplotlib qt

# %%
'''input the index from the image name and output a dataframe that has statistics for that image. This also
makes a subplot with the segmented image the original image and plot that shows where object is located'''


iter_id = 4

'''set up file names and associated image number'''
orig_img_file = orig_img_lst[iter_id]
segm_img_file = segm_img_lst[iter_id]   
image_number = img_num_arr[iter_id]

'''parse out a df that contains only information about the desired img'''
df = df_whole.loc[df_whole.ImageNumber == image_number]

'''categories for manual curation of list of objects to keep and toss'''
cats = ['ObjectNumber',
        'AreaShape_Center_X',
        'AreaShape_Center_Y',
        'AreaShape_Area',
           'AreaShape_Eccentricity']
df = df[cats] #keep only a couple of the categories

'''read in the original image'''
os.chdir(orig_img_dir)
orig_img = io.imread(orig_img_file)


'''read in the segmented image'''
os.chdir(segm_img_dir)
segm_img = io.imread(segm_img_file)


'''make a plot that contains the orignal image, the segmented image as well as a quick plot using the x and y positions from the data frame'''
fig, axes = plt.subplots(1, 3)
axes = axes.flatten()
axes[0].imshow(orig_img)
axes[1].imshow(segm_img)
axes[2].scatter(df.AreaShape_Center_X, df.AreaShape_Center_Y)
axes[2].invert_yaxis()



#df.AreaShape_Center_Y = np.subtract(2047, df.AreaShape_Center_Y) #this makes the AreaShape_Center_Y match up with FIJI
#df_in = df.loc[df.AreaShape_Area > 20000] #this is qualative parameter 
#df_in = df_in.loc[df_in.AreaShape_Eccentricity > .55] #this was qualatatively determined as well
#df_out_area = df.loc[df.AreaShape_Area <= 20000] #df of things filtered out by area
#df_out_ecc = df.loc[df.AreaShape_Eccentricity <= .55] #df of entires filtered out by eccentricity

# %%
df.sort_values('AreaShape_Center_X', inplace = True)
#df.loc[df.AreaShape_Area]
df.loc[df.AreaShape_Area >= 10000]
# shape 4, 29
# size 5, 22, 

'''this is list of objects not included in the out list'''
out_obj_lst_annot = [11, 10, 15, 28, 23, 26, 27, 30, 19, 13,7]
out_obj_lst_size = np.array(df.loc[df.AreaShape_Area < 10000].ObjectNumber)
out_obj_lst_concat = np.concatenate([out_obj_lst_annot, out_obj_lst_size])
in_obj_lst = np.setdiff1d(np.unique(df.ObjectNumber), out_obj_lst_concat, assume_unique=False)
# Out:
#      ObjectNumber  AreaShape_Center_X  AreaShape_Center_Y  AreaShape_Area  \
# 242            11               179.0               550.0           23100
# 246            15               205.0               752.0           59803
# 251            20               292.0              1012.0           38846
# 256            25               326.0              1680.0           61249
# 241            10               340.0               478.0           20783
# 239             8               389.0               220.0           26395
# 260            29               445.0              1952.0           21188
# 245            14               521.0               651.0           45711
# 255            24               682.0              1616.0           43791
# 259            28               761.0              1874.0           19425
# 244            13               912.0               575.0           56594
# 247            16               973.0               755.0           24582
# 253            22              1053.0              1233.0           42082
# 257            26              1150.0              1685.0          102417
# 250            19              1192.0               956.0           29299
# 254            23              1383.0              1565.0           27632
# 238             7              1471.0               213.0           21525
# 248            17              1490.0               750.0           28601
# 252            21              1490.0              1024.0           21661
# 258            27              1571.0              1828.0           49811
# 261            30              1659.0              2047.0           47282
# 243            12              1695.0               536.0           43319
# 249            18              1757.0               819.0           26538
# 240             9              1921.0               303.0           23043
#
#      AreaShape_Eccentricity
# 242                0.566942
# 246                0.749251
# 251                0.539826
# 256                0.608029
# 241                0.572275
# 239                0.731664
# 260                0.712576
# 245                0.630092
# 255                0.191790
# 259                0.542344
# 244                0.852683
# 247                0.638841
# 253                0.416653
# 257                0.915381
# 250                0.532747
# 254                0.476170
# 238                0.357508
# 248                0.374110
# 252                0.576199
# 258                0.682508
# 261                0.800328
# 243                0.509826
# 249                0.614808
# 240                0.259273

# %%
'''this is list of objects not included in the out list'''
out_obj_lst_annot = [11, 10, 15, 28, 23, 26, 27, 30, 19, 13,7]
out_obj_lst_size = np.array(df.loc[df.AreaShape_Area < 10000].ObjectNumber)
out_obj_lst_concat = np.concatenate([out_obj_lst_annot, out_obj_lst_size])
in_obj_lst = np.setdiff1d(np.unique(df.ObjectNumber), out_obj_lst_concat, assume_unique=False)

# %%
df_in = df_

# %%
dict_name = orig_img_file[:-11]

os.chdir(r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests\in_out_csvs')

df_out_shape.to_csv('out_shape_' + dict_name + '.csv')
df_out_size.to_csv('out_size_' + dict_name + '.csv')
df_out.to_csv('out_' + dict_name + '.csv')
df_in.to_csv('in_' + dict_name + '.csv')
# Out:
# array([ 8,  9, 12, 14, 16, 17, 18, 20, 21, 22, 24, 25, 29], dtype=int64)

# %%
np.array(df.loc[df.AreaShape_Area < 10000].ObjectNumber)
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
out_obj_lst_shape = [4, 29, 28, 40, 10, 11, 25]
out_obj_lst_size = [5, 22, 2, 3, 17, 10, 16, 9, 26, 27, 14, 23, 3, 31]
out_obj_lst_concat = np.concatenate([out_obj_lst_shape, out_obj_lst_size])

# %%
 list((df.loc[df.AreaShape_Area < 1000].ObjectNumber))
# Out:
# [17, 10, 16, 9, 26, 27, 14, 23, 3, 31]

# %%
'''manually curated list of objects to exclude from each'''

# %%
'''this is list of objects not included in the out list'''
in_obj_lst = np.setdiff1d(np.unique(df.ObjectNumber), out_obj_lst_concat, assume_unique=False)

# %%
'''This is same as above it just uses all of the shape categories'''



'''set up file names and associated image number'''
#orig_img_file = orig_img_lst[iter_id]
#segm_img_file = segm_img_lst[iter_id]   
image_number = img_num_arr[iter_id]

'''parse out a df that contains only information about the desired img'''
df = df_whole.loc[df_whole.ImageNumber == image_number]




cats = ['ImageNumber',
 'ObjectNumber',
 'AreaShape_Area',
 'AreaShape_Compactness',
 'AreaShape_Eccentricity',
 'AreaShape_EulerNumber',
 'AreaShape_Extent',
 'AreaShape_FormFactor',
 'AreaShape_MajorAxisLength',
 'AreaShape_MaxFeretDiameter',
 'AreaShape_MaximumRadius',
 'AreaShape_MeanRadius',
 'AreaShape_MedianRadius',
 'AreaShape_MinFeretDiameter',
 'AreaShape_MinorAxisLength',
 'AreaShape_Orientation',
 'AreaShape_Perimeter',
 'AreaShape_Solidity']

df = df[cats] #keep onl categories related to shape and size

#orig_img = io.imread(img_name)
#segm_img = io.imread(segm_img_name)


#fig, axes = plt.subplots(1, 3)
#axes = axes.flatten()
#axes[0].imshow(orig_img)
#axes[1].imshow(segm_img)
#axes[2].scatter(df.AreaShape_Center_X, df.AreaShape_Center_Y)
#axes[2].invert_yaxis()

#df.AreaShape_Center_Y = np.subtract(2047, df.AreaShape_Center_Y) #this makes the AreaShape_Center_Y match up with FIJI
#df_in = df.loc[df.AreaShape_Area > 20000] #this is qualative parameter 
#df_in = df_in.loc[df_in.AreaShape_Eccentricity > .55] #this was qualatatively determined as well
#df_out_area = df.loc[df.AreaShape_Area <= 20000] #df of things filtered out by area
#df_out_ecc = df.loc[df.AreaShape_Eccentricity <= .55] #df of entires filtered out by eccentricity

# %%
'''create dataframes and add a boolean array to indicate whether object is should be included'''

df_out_shape = df.loc[df.ObjectNumber.isin(out_obj_lst_shape)]
df_out_size = df.loc[df.ObjectNumber.isin(out_obj_lst_size)]
df_out = df.loc[df.ObjectNumber.isin(out_obj_lst_concat)]
df_in = df.loc[df.ObjectNumber.isin(in_obj_lst)]

df_out_shape['in_object'] = np.zeros(len(df_out_shape))
df_out_size['in_object'] = np.zeros(len(df_out_size))
df_out['in_object'] = np.zeros(len(df_out))
df_in['in_object'] = np.zeros(len(df_in))
df_in.in_object += 1
# Out:
# C:\Users\timdaugird\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\timdaugird\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\timdaugird\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\timdaugird\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_in
# Out:
#       ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_Compactness  \
# 2553          113             1           16841               1.176832
# 2558          113             6           43431               1.006361
# 2559          113             7           24345               1.025445
# 2560          113             8           20182               1.003121
# 2564          113            12           25409               1.015815
# 2565          113            13           72037               1.283121
# 2567          113            15           35968               1.001058
# 2570          113            18           26822               1.011423
# 2571          113            19           23463               1.014953
# 2572          113            20           14610               1.332943
# 2573          113            21           38082               1.026375
# 2576          113            24           22721               1.008278
# 2582          113            30           27944               1.003660
# 2584          113            32           24819               1.102022
# 2585          113            33           35843               1.005673
# 2586          113            34           22105               1.021571
# 2587          113            35           59978               1.008347
# 2588          113            36           25648               1.009468
# 2589          113            37           27575               1.045204
# 2590          113            38           25766               1.035847
# 2591          113            39           14652               1.080419
#
#       AreaShape_Eccentricity  AreaShape_EulerNumber  AreaShape_Extent  \
# 2553                0.794128                    1.0          0.815703
# 2558                0.379277                    1.0          0.770955
# 2559                0.586029                    1.0          0.755633
# 2560                0.306563                    1.0          0.764296
# 2564                0.492822                    1.0          0.762896
# 2565                0.854355                    1.0          0.700272
# 2567                0.261605                    1.0          0.792945
# 2570                0.352955                    1.0          0.750896
# 2571                0.522107                    1.0          0.751826
# 2572                0.874010                    1.0          0.810226
# 2573                0.543222                    1.0          0.680206
# 2576                0.460049                    1.0          0.742007
# 2582                0.336739                    1.0          0.754346
# 2584                0.725304                    1.0          0.666586
# 2585                0.387932                    1.0          0.776007
# 2586                0.578182                    1.0          0.765117
# 2587                0.446443                    1.0          0.780720
# 2588                0.424294                    1.0          0.718995
# 2589                0.661832                    1.0          0.738346
# 2590                0.605314                    1.0          0.709964
# 2591                0.636128                    1.0          0.799520
#
#       AreaShape_FormFactor  AreaShape_MajorAxisLength  \
# 2553              0.757861                 191.609942
# 2558              0.824337                 244.359045
# 2559              0.881599                 195.510380
# 2560              0.877883                 164.148024
# 2564              0.818563                 193.023461
# 2565              0.664485                 429.530937
# 2567              0.893197                 217.424993
# 2570              0.788749                 191.543668
# 2571              0.850063                 186.998188
# 2572              0.688933                 199.909699
# 2573              0.669305                 241.118107
# 2576              0.855116                 180.260910
# 2582              0.800406                 194.177385
# 2584              0.729080                 216.944661
# 2585              0.813743                 222.319864
# 2586              0.861086                 185.441097
# 2587              0.882336                 291.818912
# 2588              0.840846                 189.954981
# 2589              0.835654                 216.330349
# 2590              0.774431                 203.565847
# 2591              0.788606                 158.668075
#
#       AreaShape_MaxFeretDiameter  AreaShape_MaximumRadius  \
# 2553                  187.536663                91.831367
# 2558                  252.406418               109.895405
# 2559                  195.420060                78.492038
# 2560                  166.027106                76.922038
# 2564                  204.384442                81.498466
# 2565                  412.069169               112.058021
# 2567                  218.826415               103.464970
# 2570                  211.631756                87.091905
# 2571                  189.084637                77.665951
# 2572                  196.237101                91.000000
# 2573                  262.087772                99.849887
# 2576                  179.635743                78.236820
# 2582                  198.715878                89.470666
# 2584                  236.279496                76.367532
# 2585                  227.149730               100.044990
# 2586                  185.607112                75.742986
# 2587                  292.432898               128.786645
# 2588                  195.256242                83.438600
# 2589                  220.719279                80.529498
# 2590                  210.770017                79.611557
# 2591                  163.220709                72.801099
#
#       AreaShape_MeanRadius  AreaShape_MedianRadius  \
# 2553             33.916130               30.016662
# 2558             38.062546               33.526109
# 2559             28.609655               25.455844
# 2560             26.546631               23.345235
# 2564             29.097224               25.942244
# 2565             40.033657               36.891733
# 2567             35.597184               31.304952
# 2570             29.839417               26.172505
# 2571             28.145316               25.000000
# 2572             31.787964               28.017851
# 2573             34.974194               30.675723
# 2576             27.862700               24.596748
# 2582             30.993113               27.202941
# 2584             27.083307               23.769729
# 2585             34.948583               30.870698
# 2586             27.404306               24.186773
# 2587             45.422869               40.180837
# 2588             29.178718               25.553865
# 2589             29.558480               26.248809
# 2590             28.157056               25.000000
# 2591             28.732681               26.076810
#
#       AreaShape_MinFeretDiameter  AreaShape_MinorAxisLength  \
# 2553                  110.000000                 116.450995
# 2558                  226.282495                 226.101332
# 2559                  157.869473                 158.420110
# 2560                  155.147066                 156.244336
# 2564                  165.904069                 167.955521
# 2565                  234.581523                 223.222680
# 2567                  208.553450                 209.853175
# 2570                  177.660887                 179.215988
# 2571                  159.925579                 159.486995
# 2572                   91.000000                  97.137849
# 2573                  205.404529                 202.440103
# 2576                  158.366906                 160.052532
# 2582                  180.083379                 182.837038
# 2584                  153.337502                 149.350993
# 2585                  206.393798                 204.909583
# 2586                  152.027958                 151.302868
# 2587                  258.800000                 261.123101
# 2588                  172.452716                 172.008925
# 2589                  164.647649                 162.172431
# 2590                  170.288667                 162.035770
# 2591                  118.000000                 122.425702
#
#       AreaShape_Orientation  AreaShape_Perimeter  AreaShape_Solidity  \
# 2553               0.794501              528.438            0.992398
# 2558              30.450827              813.678            0.973669
# 2559             -41.561662              589.080            0.988469
# 2560             -38.743288              537.488            0.986292
# 2564              51.766166              624.558            0.974776
# 2565             -12.775243             1167.186            0.925479
# 2567               5.797797              711.360            0.990131
# 2570             -45.117690              653.704            0.966036
# 2571             -19.955801              588.940            0.984413
# 2572             -87.863651              516.228            0.991786
# 2573             -74.699920              845.576            0.932468
# 2576             -52.768398              577.838            0.981257
# 2582              20.623855              662.360            0.981283
# 2584              46.034719              654.048            0.962163
# 2585              14.503426              743.984            0.981677
# 2586             -51.371687              567.972            0.985554
# 2587              -3.028367              924.238            0.991405
# 2588             -56.262491              619.118            0.969111
# 2589             -65.507876              643.946            0.976971
# 2590               7.374475              646.602            0.961346
# 2591             -76.028565              483.196            0.986667
#
#       in_object
# 2553        1.0
# 2558        1.0
# 2559        1.0
# 2560        1.0
# 2564        1.0
# 2565        1.0
# 2567        1.0
# 2570        1.0
# 2571        1.0
# 2572        1.0
# 2573        1.0
# 2576        1.0
# 2582        1.0
# 2584        1.0
# 2585        1.0
# 2586        1.0
# 2587        1.0
# 2588        1.0
# 2589        1.0
# 2590        1.0
# 2591        1.0

# %%
orig_img_file[:-11]
# Out:
# 'stad447-xy03'

# %%
dict_name = orig_img_file[:-11]

os.chdir(r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests\in_out_csvs')

df_out_shape.to_csv('out_shape_' + dict_name + '.csv')
df_out_size.to_csv('out_size_' + dict_name + '.csv')
df_out.to_csv('out_' + dict_name + '.csv')
df_in.to_csv('in_' + dict_name + '.csv')

# %% [markdown]
# ### AreaShape_Eccentricity > 0.55]
# ### AreaShape_Area > 20000]

# %%
out_lst = []
for i in np.unique(df.ObjectNumber):
    if i not in (np.unique(df_parsed.ObjectNumber)):
        out_lst.append(i)
out_lst
# Out:
# [1, 14, 15, 17]

# %% [markdown]
# ### I am going to run through some quick plotting stuff in order to make sure that I am aligning everything correctly

# %%
os.chdir(r'C:\Users\timdaugird\Google Drive\legant_lab\_projects\200217_adipogen_zstacks\cell_profiler_output\dcts_output\segm_img_tests')

# %%
img = io.imread('segm-stad441-xy01_c4_mid.tiff')

# %%
df.sort_values('AreaShape_Center_X', inplace = True)

# %%
df
# Out:
#       ObjectNumber  AreaShape_Center_X  AreaShape_Center_Y  AreaShape_Area  \
# 1129             9                 0.0               831.0           30530
# 1134            14               507.0              1487.0           52714
# 1131            11               512.0              1122.0           38001
# 1125             5               560.0               410.0           36034
# 1127             7               739.0               687.0           41606
# 1123             3              1043.0               306.0           44296
# 1136            16              1074.0              1782.0           42953
# 1130            10              1292.0               951.0           35168
# 1122             2              1333.0               242.0           48785
# 1128             8              1377.0               769.0           35203
# 1135            15              1396.0              1778.0           38511
# 1137            17              1618.0              2047.0           11685
# 1126             6              1618.0               603.0           41136
# 1132            12              1686.0              1057.0           50201
# 1133            13              1905.0              1456.0           71011
# 1124             4              1907.0               240.0           58796
# 1121             1              2021.0                 0.0            5574
#
#       AreaShape_Eccentricity
# 1129                0.736340
# 1134                0.418108
# 1131                0.649745
# 1125                0.581022
# 1127                0.665967
# 1123                0.842094
# 1136                0.708331
# 1130                0.736379
# 1122                0.773322
# 1128                0.759600
# 1135                0.527268
# 1137                0.882547
# 1126                0.607290
# 1132                0.755888
# 1133                0.760172
# 1124                0.758256
# 1121                0.586942

# %%
'''this is manually curated list of objects to exclude'''
out_obj_lst = [1, 4, 12, 6, 17]

# %%
'''this is list of objects not included in the out list'''
in_obj_lst = np.setdiff1d(np.unique(df.ObjectNumber), out_obj_lst_xy01, assume_unique=False)

# %%
df_out_shape = df.loc[df.ObjectNumber.isin(out_obj_lst)]
df_in_shape = df.loc[df.ObjectNumber.isin(in_obj_lst)]

# %%
'''input the index from the image name and output a dataframe that has statistics for that image. This also
makes a subplot with the segmented image the original image and plot that shows where object is located'''

xy_id = 1 #the image number that you would like to work with 

if xy_id < 10:
    dict_name = 'stad441-xy0' + str(xy_id)
    img_name = 'stad441-xy0' + str(xy_id)+ '_c4_mid.tif'
    segm_img_name = 'segm-' + img_name + 'f'
if xy_id == 10:
    dict_name = 'stad441-xy10'
    img_name = 'stad441-xy10_c4_mid.tif'
    segm_img_name = 'segm-stad441-xy10_c4_mid.tiff'
    
image_number = img_dict[dict_name]

df = df_whole.loc[df_whole.ImageNumber == image_number]

'''these are all of the categories related to shape'''
cats = ['ImageNumber',
 'ObjectNumber',
 'AreaShape_Area',
 'AreaShape_Compactness',
 'AreaShape_Eccentricity',
 'AreaShape_EulerNumber',
 'AreaShape_Extent',
 'AreaShape_FormFactor',
 'AreaShape_MajorAxisLength',
 'AreaShape_MaxFeretDiameter',
 'AreaShape_MaximumRadius',
 'AreaShape_MeanRadius',
 'AreaShape_MedianRadius',
 'AreaShape_MinFeretDiameter',
 'AreaShape_MinorAxisLength',
 'AreaShape_Orientation',
 'AreaShape_Perimeter',
 'AreaShape_Solidity']

orig_img = io.imread(img_name)
segm_img = io.imread(segm_img_name)


fig, axes = plt.subplots(1, 3)
axes = axes.flatten()
axes[0].imshow(orig_img)
axes[1].imshow(segm_img)
axes[2].scatter(df.AreaShape_Center_X, df.AreaShape_Center_Y)
axes[2].invert_yaxis()


df = df[cats] #keep only a couple of the categories

# %%
shape_cats = cats = ['ImageNumber',
 'ObjectNumber',
 'AreaShape_Area',
 'AreaShape_Compactness',
 'AreaShape_Eccentricity',
 'AreaShape_EulerNumber',
 'AreaShape_Extent',
 'AreaShape_FormFactor',
 'AreaShape_MajorAxisLength',
 'AreaShape_MaxFeretDiameter',
 'AreaShape_MaximumRadius',
 'AreaShape_MeanRadius',
 'AreaShape_MedianRadius',
 'AreaShape_MinFeretDiameter',
 'AreaShape_MinorAxisLength',
 'AreaShape_Orientation',
 'AreaShape_Perimeter',
 'AreaShape_Solidity']

# %%
df_out_shape = df.loc[df.ObjectNumber.isin(out_obj_lst_xy01)]

# %%
df_out_shape
# Out:
#       ImageNumber  ObjectNumber  AreaShape_Area  AreaShape_Center_X  \
# 1121           51             1            5574              2021.0
# 1124           51             4           58796              1907.0
# 1126           51             6           41136              1618.0
# 1132           51            12           50201              1686.0
# 1137           51            17           11685              1618.0
#
#       AreaShape_Center_Y  AreaShape_Center_Z  AreaShape_Compactness  \
# 1121                 0.0                 1.0               1.056672
# 1124               240.0                 1.0               1.157706
# 1126               603.0                 1.0               1.027456
# 1132              1057.0                 1.0               1.144581
# 1137              2047.0                 1.0               1.392890
#
#       AreaShape_Eccentricity  AreaShape_EulerNumber  AreaShape_Extent  ...  \
# 1121                0.586942                    1.0          0.867684  ...
# 1124                0.758256                    1.0          0.673262  ...
# 1126                0.607290                    1.0          0.790773  ...
# 1132                0.755888                    1.0          0.701092  ...
# 1137                0.882547                    1.0          0.729446  ...
#
#       AreaShape_MajorAxisLength  AreaShape_MaxFeretDiameter  \
# 1121                  95.048850                  101.788997
# 1124                 347.999508                  385.135041
# 1126                 256.329891                  255.227350
# 1132                 319.338900                  326.938832
# 1137                 183.885937                  194.177754
#
#       AreaShape_MaximumRadius  AreaShape_MeanRadius  AreaShape_MedianRadius  \
# 1121                62.032250             24.575192               22.472205
# 1124               106.733313             42.552462               40.311289
# 1126               101.019800             37.141489               33.015148
# 1132               108.664622             37.092228               32.449961
# 1137                79.158070             27.726242               24.596748
#
#       AreaShape_MinFeretDiameter  AreaShape_MinorAxisLength  \
# 1121                   72.000000                  76.954303
# 1124                  239.021512                 226.880744
# 1126                  202.518957                 203.649077
# 1132                  220.000000                 209.071373
# 1137                   82.000000                  86.467556
#
#       AreaShape_Orientation  AreaShape_Perimeter  AreaShape_Solidity
# 1121              14.943611              292.114            0.988999
# 1124              62.118274             1052.404            0.938499
# 1126              84.770382              771.398            0.989476
# 1132              78.223569              939.238            0.950831
# 1137              -5.864901              485.438            0.991262
#
# [5 rows x 21 columns]

# %%
df_in_shape = df.loc[df.ObjectNumber.isin(in_obj_lst_xy01)]

# %%
tstat_lst = []
pval_lst = []

for i in shape_cats:
    tstat, pval = stats.ttest_ind(np.array(df_in_shape[i]), np.array(df_out_shape[i]))
    tstat_lst.append(tstat)
    pval_lst.append(pval)

# %%
ttest_df = pd.DataFrame({'cat' : shape_cats,
                        'tstat' : tstat_lst,
                        'pval' : pval_lst})

# %%
ttest_df.sort_values('pval', inplace = True)

# %%
ttest_df
# Out:
#                            cat     tstat      pval
# 3           AreaShape_Center_X -3.223927  0.005679
# 18       AreaShape_Orientation -2.395529  0.030087
# 17   AreaShape_MinorAxisLength  1.573496  0.136456
# 6        AreaShape_Compactness -1.397498  0.182592
# 16  AreaShape_MinFeretDiameter  1.300991  0.212893
# 19         AreaShape_Perimeter  1.212995  0.243889
# 2               AreaShape_Area  1.155549  0.265941
# 11   AreaShape_MajorAxisLength  1.096648  0.290090
# 14        AreaShape_MeanRadius  0.952337  0.356021
# 15      AreaShape_MedianRadius  0.829658  0.419741
# 13     AreaShape_MaximumRadius  0.800142  0.436118
# 10        AreaShape_FormFactor  0.778041  0.448644
# 12  AreaShape_MaxFeretDiameter  0.727578  0.478076
# 9             AreaShape_Extent -0.618590  0.545466
# 7       AreaShape_Eccentricity -0.598174  0.558648
# 4           AreaShape_Center_Y  0.587486  0.565617
# 1                 ObjectNumber  0.514799  0.614196
# 20          AreaShape_Solidity  0.191043  0.851054
# 0                  ImageNumber       NaN       NaN
# 5           AreaShape_Center_Z       NaN       NaN
# 8        AreaShape_EulerNumber       NaN       NaN

# %%
'''this is old version of this script that I used when I was only looking at images from the STAD441'''


'''input the index from the image name and output a dataframe that has statistics for that image. This also
makes a subplot with the segmented image the original image and plot that shows where object is located'''

xy_id = 1 #the image number that you would like to work with 

if xy_id < 10:
    dict_name = 'stad441-xy0' + str(xy_id)
    img_name = 'stad441-xy0' + str(xy_id)+ '_c4_mid.tif'
    segm_img_name = 'segm-' + img_name + 'f'
if xy_id == 10:
    dict_name = 'stad441-xy10'
    img_name = 'stad441-xy10_c4_mid.tif'
    segm_img_name = 'segm-stad441-xy10_c4_mid.tiff'
    
image_number = img_dict[dict_name]

df = df_whole.loc[df_whole.ImageNumber == image_number]

cats = ['ObjectNumber',
        'AreaShape_Center_X',
        'AreaShape_Center_Y',
        'AreaShape_Area',
           'AreaShape_Eccentricity']

orig_img = io.imread(img_name)
segm_img = io.imread(segm_img_name)


fig, axes = plt.subplots(1, 3)
axes = axes.flatten()
axes[0].imshow(orig_img)
axes[1].imshow(segm_img)
axes[2].scatter(df.AreaShape_Center_X, df.AreaShape_Center_Y)
axes[2].invert_yaxis()


df = df[cats] #keep only a couple of the categories
#df.AreaShape_Center_Y = np.subtract(2047, df.AreaShape_Center_Y) #this makes the AreaShape_Center_Y match up with FIJI
#df_in = df.loc[df.AreaShape_Area > 20000] #this is qualative parameter 
#df_in = df_in.loc[df_in.AreaShape_Eccentricity > .55] #this was qualatatively determined as well
#df_out_area = df.loc[df.AreaShape_Area <= 20000] #df of things filtered out by area
#df_out_ecc = df.loc[df.AreaShape_Eccentricity <= .55] #df of entires filtered out by eccentricity
